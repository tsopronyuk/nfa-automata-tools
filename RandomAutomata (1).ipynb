# %% [markdown]
# ## **Побудова діаграми переходів автомату**

# %%
# !pip3 install pysimpleautomata

#https://pysimpleautomata.readthedocs.io/en/latest/tutorial.html

# %%
import random
from graphviz import Digraph
from IPython.display import display, Markdown, HTML, Image

def generate_random_alphabet():
    """Генерує випадковий алфавіт (2-3 символи)"""
    letters = ['a', 'b', 'c', 'd', 'f', 'x', 'y', 'z']
    return random.sample(letters, random.randint(2, 3))

def generate_random_nfa(prefix, sigma=None, num_states=None):
    """Генерує випадковий НКА з заданим алфавітом."""
    n = num_states if num_states else random.choice([3, 4])
    sigma = sigma if sigma else generate_random_alphabet()

    m = random.choice([2, 3]) if n > 2 else 2
    m = min(m, n)

    S = [f'{prefix}{i}' for i in range(1, n+1)]
    q0 = f'{prefix}1'
    F = random.sample(S, m)

    delta = {state: {symbol: set() for symbol in sigma} for state in S}

    # Забезпечуємо досяжність
    for i in range(2, n+1):
        qj = f'{prefix}{random.choice(range(1, i))}'
        s = random.choice(sigma)
        delta[qj][s].add(f'{prefix}{i}')

    # Додаємо випадкові переходи
    for q in S:
        for s in sigma:
            for t in S:
                if t == q0:
                    continue
                if random.random() < 0.2:
                    delta[q][s].add(t)

    return S, sigma, delta, q0, F

def draw_nfa_for_print(S, sigma, delta, q0, F, title):
    """Створює компактний графік НКА для друку."""
    dot = Digraph(title, format='png')
    dot.attr(rankdir='LR',
             size='6,3',  # Зменшений розмір
             margin='0.1',
             nodesep='0.3',
             ranksep='0.3',
             fontsize='9')

    dot.node('start', shape='none', width='0.15', height='0.15')
    dot.edge('start', q0, arrowsize='0.4')

    for state in S:
        if state in F:
            dot.node(state, shape='doublecircle', width='0.5', height='0.5', fixedsize='true')
        else:
            dot.node(state, shape='circle', width='0.5', height='0.5', fixedsize='true')

    for from_state in delta:
        for symbol in delta[from_state]:
            for to_state in delta[from_state][symbol]:
                dot.edge(from_state, to_state, label=symbol, arrowsize='0.4', fontsize='9')

    return dot

def display_two_nfas(nfa1, nfa2, op_name, titles=("A", "B")):
    """Відображає два компактні автомати поруч."""
    # Використовуємо алфавіт першого автомата для другого
    nfa2 = (nfa2[0], nfa1[1], nfa2[2], nfa2[3], nfa2[4])

    dot1 = draw_nfa_for_print(*nfa1, f"{titles[0]} ({op_name})")
    dot2 = draw_nfa_for_print(*nfa2, f"{titles[1]} ({op_name})")

    display(HTML(f"""
    <div style='display: flex; justify-content: center; gap: 30px; margin: 10px 0; page-break-inside: avoid;'>
        <div style='flex: 1;'>{dot1.pipe(format='svg').decode('utf-8')}</div>
        <div style='flex: 1;'>{dot2.pipe(format='svg').decode('utf-8')}</div>
    </div>
    """))

def generate_variant(variant_num):
    """Генерує варіант завдання з примусовим розривом сторінки."""
    # Початок нового варіанту - нова сторінка
    display(Markdown(f"<div style='page-break-before: always;'><h2>Варіант {variant_num}</h2></div>"))

    # Конкатенація
    display(Markdown("### 1. Конкатенація (A · B)"))
    sigma_conc = generate_random_alphabet()
    nfa1 = generate_random_nfa('q', sigma=sigma_conc)
    nfa2 = generate_random_nfa('p', sigma=sigma_conc)
    display_two_nfas(nfa1, nfa2, "Конкатенація", ("A", "B"))
    #display(Markdown("**Завдання:** Побудуйте НКА для (A · B)"))

    display(Markdown("---"))

    # Альтернатива
    display(Markdown("### 2. Альтернатива (C ∪ D)"))
    sigma_union = generate_random_alphabet()
    nfa3 = generate_random_nfa('q', sigma=sigma_union)
    nfa4 = generate_random_nfa('p', sigma=sigma_union)
    display_two_nfas(nfa3, nfa4, "Альтернатива", ("C", "D"))
    #display(Markdown("**Завдання:** Побудуйте НКА для (C ∪ D)"))

    display(Markdown("---"))

    # Ітерації
    display(HTML("""
    <div style="display: flex; justify-content: space-between; width: 100%;">
        <div style="width: 48%; text-align: center;"><h3>3. Ітерація (M*)</h3></div>
        <div style="width: 48%; text-align: center;"><h3>4. Ітерація (M+)</h3></div>
    </div>
    """))

    sigma_iter = generate_random_alphabet()
    nfa5 = generate_random_nfa('q', sigma=sigma_iter)
    nfa6 = generate_random_nfa('p', sigma=sigma_iter)

    display_two_nfas(nfa5, nfa6, "Ітерація", ("A*", "A+"))
    #display(Markdown("**Завдання:** Побудуйте окремо НКА для A* та A+"))
    display(Markdown("---"))

# Генеруємо 20 варіантів
for i in range(1, 21):
    generate_variant(i)
    # Додатковий розрив після варіанту (якщо він не вмістився на одну сторінку)
    display(Markdown("<div style='page-break-after: always;'></div>"))
# Out:
# <div style='page-break-before: always;'><h2>Варіант 1</h2></div>
# ### 1. Конкатенація (A · B)
#     <div style='display: flex; justify-content: center; gap: 30px; margin: 10px 0; page-break-inside: avoid;'>
#         <div style='flex: 1;'><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: A (Конкатенація) Pages: 1 -->
# <svg width="270pt" height="122pt"
#  viewBox="7.20 7.20 263.20 115.20" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(11.2 111.2)">
# <title>A (Конкатенація)</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-104 252,-104 252,4 -4,4"/>
# <!-- start -->
# <g id="node1" class="node">
# <title>start</title>
# ...

# %%
def generate_variant(variant_num):
    """Генерує варіант завдання з примусовим розривом сторінки."""
    # Початок нового варіанту - нова сторінка
    display(Markdown(f"<div style='page-break-before: always;'><h2>Variant  {variant_num}</h2></div>"))

    # Конкатенація
    display(Markdown("### 1. Concatenation (A · B)"))
    sigma_conc = generate_random_alphabet()
    nfa1 = generate_random_nfa('q', sigma=sigma_conc)
    nfa2 = generate_random_nfa('p', sigma=sigma_conc)
    display_two_nfas(nfa1, nfa2, "Конкатенація", ("A", "B"))
    #display(Markdown("**Завдання:** Побудуйте НКА для (A · B)"))

    display(Markdown("---"))

    # Альтернатива
    display(Markdown("### 2. Union (C ∪ D)"))
    sigma_union = generate_random_alphabet()
    nfa3 = generate_random_nfa('q', sigma=sigma_union)
    nfa4 = generate_random_nfa('p', sigma=sigma_union)
    display_two_nfas(nfa3, nfa4, "Альтернатива", ("C", "D"))
    #display(Markdown("**Завдання:** Побудуйте НКА для (C ∪ D)"))

    display(Markdown("---"))

    # Ітерації
    display(HTML("""
    <div style="display: flex; justify-content: space-between; width: 100%;">
        <div style="width: 48%; text-align: center;"><h3>3. Iteration (M*)</h3></div>
        <div style="width: 48%; text-align: center;"><h3>4. Iteration (M+)</h3></div>
    </div>
    """))

    sigma_iter = generate_random_alphabet()
    nfa5 = generate_random_nfa('q', sigma=sigma_iter)
    nfa6 = generate_random_nfa('p', sigma=sigma_iter)

    display_two_nfas(nfa5, nfa6, "Ітерація", ("A*", "A+"))
    #display(Markdown("**Завдання:** Побудуйте окремо НКА для A* та A+"))
    display(Markdown("---"))

# Генеруємо 10 варіантів
for i in range(1, 11):
    generate_variant(i)
    # Додатковий розрив після варіанту (якщо він не вмістився на одну сторінку)
    display(Markdown("<div style='page-break-after: always;'></div>"))
# Out:
# <div style='page-break-before: always;'><h2>Variant  1</h2></div>
# ### 1. Concatenation (A · B)
#     <div style='display: flex; justify-content: center; gap: 30px; margin: 10px 0; page-break-inside: avoid;'>
#         <div style='flex: 1;'><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: A (Конкатенація) Pages: 1 -->
# <svg width="331pt" height="196pt"
#  viewBox="7.20 7.20 324.20 188.68" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(11.2 184.68)">
# <title>A (Конкатенація)</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-177.48 313,-177.48 313,4 -4,4"/>
# <!-- start -->
# <g id="node1" class="node">
# <title>start</title>
# ...

# %% [markdown]
# **Прикладна математика**
#
# **УДК 519.713:004.8**
#
# **Т. М. Сопронюк, кандидат фізико-математичних наук, доцент, доцент кафедри прикладної математики та інформаційних технологій**
# Чернівецький національний університет імені Юрія Федьковича
# ORCID: [your ORCID]
#
# **Автоматизована робота зі скінченними автоматами: інструментарій для навчання в епоху штучного інтелекту**
#
# *Стаття присвячена проблемі збереження об’єктивності оцінювання знань студентів в умовах широкого доступу до інструментів штучного інтелекту, зокрема великих мовних моделей типу ChatGPT. Дослідження зосереджене на дисципліні «Теорія формальних мов та автоматів», де традиційні форми завдань (таблиці переходів) легко розв’язуються сучасними ШІ-моделями. Метою роботи є розробка програмного забезпечення для автоматизованої генерації, детермінізації та візуалізації скінченних автоматів, яке дозволяє швидко створювати індивідуальні варіанти завдань у візуальному форматі (діаграми переходів). Система включає генератор випадкових НКА з гарантованою досяжністю станів та контрольованою щільністю переходів, модуль візуалізації з налаштованими параметрами, функцію парного відображення автоматів для операцій конкатенації та альтернативи, генератор варіантів завдань (20 варіантів із завданнями на конкатенацію, альтернативу та ітерацію) та алгоритм детермінізації НКА, що зчитує автомати з текстових файлів і візуалізує отриманий ДКА. Експериментальні результати показують, що завдання у візуальному форматі значно знижують успішність розв’язування ШІ, а тестування на студентах підтверджує зниження використання ШІ при незначному впливі на академічну успішність. Розроблене програмне забезпечення може бути використане у викладанні курсів з теорії автоматів та мовних процесорів.*
#
# **Ключові слова:** *скінченні автомати, недетермінований автомат, детермінізація, генерація автоматів, візуалізація, штучний інтелект, ChatGPT, навчальний процес, Python, Jupyter Notebook, graphviz.*
#
# ---
#
# **T. M. Sopronyuk, Candidate of Physical and Mathematical Sciences, Associate Professor, Associate Professor at the Department of Applied Mathematics and Information Technologies**
# Yuriy Fedkovych Chernivtsi National University
# ORCID: [your ORCID]
#
# **Automated work with finite automata: a tool for teaching in the era of artificial intelligence**
#
# *The article addresses the problem of maintaining objectivity in student assessment in the context of widespread access to artificial intelligence tools, particularly large language models such as ChatGPT. The study focuses on the discipline of formal languages and automata theory, where traditional task formats (transition tables) are easily solved by modern AI models. The purpose of the work is to develop software for automated generation, determinization, and visualization of finite automata, enabling rapid creation of individual assignment variants in visual format (transition diagrams). The system includes a random NFA generator with guaranteed state reachability and controlled transition density, a visualization module with customizable parameters, a pairwise automaton display function for concatenation and union operations, an assignment variant generator (20 variants with concatenation, union, and iteration tasks), and an NFA determinization algorithm that reads automata from text files and visualizes the resulting DFA. Experimental results show that visual format tasks significantly reduce AI solution success, while student testing confirms reduced AI usage with minimal impact on academic performance. The developed software can be used in teaching courses on automata theory and language processors.*
#
# **Key words:** *finite automata, nondeterministic automaton, determinization, automaton generation, visualization, artificial intelligence, ChatGPT, educational process, Python, Jupyter Notebook, graphviz.*
#
# ---
#
# **Постановка проблеми.** У сучасному освітньому процесі дедалі більшого поширення набувають інструменти штучного інтелекту (ШІ), зокрема великі мовні моделі (LLM) такі як ChatGPT, Claude, Gemini та інші [7; 8]. Ці інструменти демонструють вражаючі можливості у розв’язуванні типових навчальних завдань, що створює серйозний виклик для системи оцінювання знань студентів. Особливо гостро ця проблема стоїть у технічних дисциплінах, де задачі часто мають формалізований характер і можуть бути легко автоматизовані [9, с. 434–436].
#
# Теорія формальних мов та автоматів є фундаментальною дисципліною у підготовці фахівців з комп’ютерних наук [1; 4]. Традиційні форми завдань у цьому курсі включають побудову недетермінованих скінченних автоматів (НКА) для заданих регулярних виразів, виконання операцій конкатенації, альтернативи та ітерації над автоматами, а також детермінізацію НКА [5]. Як показують дослідження, сучасні ШІ-моделі здатні ефективно розв’язувати такі завдання, якщо вони представлені у формалізованому вигляді — наприклад, у вигляді таблиць переходів.
#
# Одним із перспективних підходів до збереження об’єктивності оцінювання є перехід від табличного формату до візуального (діаграми переходів), який вимагає від студента не лише знання алгоритмів, але й навичок інтерпретації графічних структур. Однак ручне створення великої кількості індивідуальних варіантів завдань із візуальним представленням автоматів є надзвичайно трудомістким для викладача.
#
# Таким чином, актуальним є створення інструментальних засобів для автоматизованої генерації таких завдань, які дозволяють швидко створювати велику кількість унікальних варіантів, візуалізувати автомати, демонструвати процес детермінізації та забезпечувати парне порівняння автоматів для різних операцій.
#
# ---
#
# **Аналіз останніх досліджень і публікацій.** Проблема впливу штучного інтелекту на освітній процес стала предметом інтенсивних досліджень у 2023–2026 роках. У роботі Ло [7] проведено масштабне дослідження можливостей ChatGPT у розв’язуванні академічних завдань з різних дисциплін. Автор демонструє, що модель здатна успішно виконувати завдання з програмування, математики та інженерних дисциплін, досягаючи рівня, порівнянного зі студентами-відмінниками. Боммасані та ін. [8] досліджують етичні аспекти використання ШІ в освіті, наголошуючи на необхідності перегляду методів оцінювання. Автори пропонують зосередитися на завданнях, які вимагають критичного мислення, творчого підходу та глибокого розуміння матеріалу, а не просто формального застосування алгоритмів.
#
# У контексті викладання теорії автоматів важливими є дослідження Роджер та Фінлі [10], які розробили освітнє середовище JFLAP, що дозволяє студентам інтерактивно працювати з автоматами. JFLAP підтримує візуалізацію автоматів, виконання операцій конкатенації, альтернативи та ітерації, а також детермінізацію. Однак JFLAP не пропонує функціоналу автоматизованої генерації індивідуальних завдань — кожен автомат потрібно вводити вручну, що значно обмежує можливість створення великої кількості унікальних варіантів.
#
# Бібліотека PySimpleAutomata [11] надає базові інструменти для роботи з автоматами в Python, включаючи реалізацію алгоритму детермінізації. Однак вона не містить функціоналу для генерації випадкових автоматів, а її візуалізація обмежується форматом DOT, що вимагає додаткових інструментів для перетворення у зображення. Бібліотека automata-lib [12] пропонує реалізацію основних алгоритмів, але її візуалізація є ще більш обмеженою.
#
# У роботі Сопронюк, Сопронюк та Дробот [3] розглянуто фази побудови мовного процесора, що базується на теорії автоматів, та наведено практичні аспекти реалізації. У навчальному посібнику Сопронюк [4] детально розглянуто теоретичні основи мовних процесорів та формальних мов, а також наведено практичні приклади реалізації скінченних автоматів. У тезах Паранчич та Сопронюк [5] описано навчальний тренажер для операцій з недетермінованими скінченними автоматами, що демонструє можливості візуалізації та інтерактивної роботи з автоматами.
#
# Окремо слід відзначити навчальний посібник Петришина та Сопронюк [6], в якому було застосовано підхід до автоматизованої генерації випадкових варіантів індивідуальних завдань для студентів — у контексті розв’язування диференціальних рівнянь з імпульсною дією. Цей підхід до створення індивідуальних завдань шляхом генерації випадкових параметрів задач виявився ефективним і був адаптований у даній роботі для потреб теорії автоматів.
#
# Розроблена в рамках цієї статті система розвиває ідеї, закладені в цих роботах [3; 4; 5; 6], додаючи автоматизовану генерацію та парну візуалізацію.
#
# Проблема автоматизованої генерації випадкових автоматів досліджувалася в роботах Табакова та Варді [13], Альмейди зі співавторами [14], де запропоновано методи забезпечення досяжності станів та регулювання щільності переходів. Однак ці дослідження зосереджені на теоретичних аспектах генерації, а не на створенні практичних інструментів для навчання.
#
# Таким чином, існує потреба в розробці інструментальних засобів, які поєднують генерацію випадкових НКА, їх візуалізацію, автоматичне формування варіантів завдань та детермінізацію, а також забезпечують парне порівняння автоматів для операцій конкатенації та альтернативи.
#
# ---
#
# **Мета статті.** Метою цієї роботи є розробка програмного забезпечення для автоматизованої генерації, детермінізації та візуалізації скінченних автоматів, яке дозволяє:
#
# 1. генерувати випадкові недетерміновані скінченні автомати із контрольованими параметрами (кількість станів, розмір алфавіту, щільність переходів);
# 2. візуалізувати автомати у вигляді діаграм переходів із налаштованими параметрами, придатними для вставки в навчальні матеріали;
# 3. забезпечувати парне відображення двох автоматів поруч для операцій конкатенації та альтернативи;
# 4. автоматично формувати індивідуальні варіанти завдань для студентів (20 і більше варіантів) з операціями конкатенації, альтернативи та ітерації;
# 5. виконувати детермінізацію НКА з візуалізацією отриманого ДКА;
# 6. дослідити ефективність візуального формату представлення автоматів як засобу протидії автоматичному розв’язуванню завдань штучним інтелектом.
#
# ---
#
# **Виклад основного матеріалу.** Для досягнення поставленої мети було розроблено програмний модуль на мові Python із використанням бібліотек graphviz [15] для візуалізації та IPython.display для відображення результатів у середовищі Jupyter Notebook. Програма складається з чотирьох основних компонентів: генератора випадкових НКА, модуля візуалізації, генератора варіантів завдань та модуля детермінізації.
#
# *2.1. Формальне визначення скінченних автоматів.*
#
# Скінченний автомат (СА) — це математична модель дискретної системи, яка має скінченну кількість станів і переходить між ними під впливом вхідних символів. Формально, НКА визначається як п’ятірка:
#
# A = (Q, Σ, δ, q₀, F),
#
# де:
# - Q — скінченна множина станів;
# - Σ — скінченний алфавіт (множина вхідних символів);
# - δ: Q × Σ → 2^Q — функція переходів, що відображає пару (стан, символ) у множину можливих наступних станів;
# - q₀ ∈ Q — початковий стан;
# - F ⊆ Q — множина фінальних (приймальних) станів.
#
# На відміну від детермінованого скінченного автомата (ДКА), у НКА функція переходів може повертати декілька станів (включаючи порожню множину), що відображає неоднозначність поведінки. ДКА є окремим випадком НКА, де для кожної пари (стан, символ) функція переходів повертає не більше одного стану, тобто δ: Q × Σ → Q.
#
# *2.2. Генератор випадкових НКА.*
#
# Розроблений метод генерації випадкових НКА базується на принципі забезпечення досяжності всіх станів із початкового. Це важлива властивість для навчальних завдань, оскільки недосяжні стани не впливають на мову автомата, але можуть заплутувати студентів.
#
# **Алгоритм 1. Генерація випадкового НКА**
#
# *Вхід:* кількість станів n ∈ {3, 4, 5}, розмір алфавіту |Σ| ∈ {2, 3}, щільність переходів p = 0.2
# *Вихід:* НКА A = (Q, Σ, δ, q₀, F)
#
# 1. Q ← {q₁, q₂, …, qₙ}
# 2. q₀ ← q₁
# 3. F ← випадковий вибір m станів з Q, де m ∈ [2, ⌊n/2⌋]
# 4. Σ ← випадковий вибір 2–3 символів з набору {a, b, c, d, f, x, y, z}
# 5. Ініціалізувати δ(q, a) ← ∅ для всіх q ∈ Q, a ∈ Σ
# 6. for i = 2 to n:
# 7.     qⱼ ← випадковий стан з {q₁, …, qᵢ₋₁}
# 8.     a ← випадковий символ з Σ
# 9.     δ(qⱼ, a) ← δ(qⱼ, a) ∪ {qᵢ}
# 10. for кожного q ∈ Q та a ∈ Σ:
# 11.     for кожного t ∈ Q, t ≠ q₀:
# 12.         if random() < p:
# 13.             δ(q, a) ← δ(q, a) ∪ {t}
# 14. return (Q, Σ, δ, q₀, F)
#
# Ключовою особливістю алгоритму є гарантія досяжності всіх станів (кроки 6–9): для кожного стану qᵢ (i ≥ 2) додається перехід з деякого попереднього стану qⱼ (j < i), що гарантує існування шляху від q₀ до кожного стану. Це усуває необхідність додаткового етапу очищення автомата від недосяжних станів, який часто потрібен у загальних методах генерації.
#
# Вибір параметрів n ∈ {3, 4, 5} та |Σ| ∈ {2, 3} зумовлений навчальними цілями: автомати з 3–5 станами є достатньо складними для демонстрації основних концепцій, але не надто громіздкими для ручної побудови студентами. Щільність переходів p = 0.2 забезпечує помірну кількість недетермінізму — достатньо цікавого для аналізу, але не надто складного.
#
# На рис. 1 наведено приклад згенерованого НКА з параметрами n = 4, Σ = {0, 1}.
#
# [ТУТ МАЄ БУТИ РИСУНОК 1: приклад згенерованого НКА]
#
# **Рис. 1. Приклад згенерованого недетермінованого скінченного автомата (НКА) з чотирма станами та алфавітом {0, 1}**
# *Джерело: розроблено автором*
#
# *2.3. Модуль візуалізації.*
#
# Для візуалізації автоматів використовується бібліотека graphviz [15], яка дозволяє генерувати графіки у форматі DOT та зберігати їх у вигляді зображень. Розроблена функція draw_nfa_for_print() реалізує компактне відображення автоматів із налаштованими параметрами:
#
# - Розмір зображення: 6×3 дюйми — оптимально для вставки в текст та розміщення двох автоматів поруч на одній сторінці формату A4;
# - Відстані між вузлами: nodesep = 0.3, ranksep = 0.3 — забезпечують компактне розташування без накладання елементів;
# - Розмір шрифту: 9 pt для написів на ребрах, 12 pt для станів — забезпечує читабельність при зменшеному розмірі зображення;
# - Форма вузлів: початковий стан позначається невидимою вершиною зі стрілкою; фінальні стани — подвійними колами; звичайні — одинарними.
#
# *2.3.1. Парне відображення автоматів.*
#
# Важливою особливістю розробленої системи є можливість парного відображення двох автоматів поруч, що необхідно для візуалізації операцій конкатенації та альтернативи. Для цього реалізовано функцію display_two_nfas(), яка виконує такі дії:
#
# 1. Узгодження алфавітів: використовує алфавіт першого автомата для другого, що забезпечує коректність подальших операцій. Якщо автомати мають різні алфавіти, операції конкатенації та альтернативи вимагають однакового алфавіту, тому це узгодження є критично важливим.
# 2. Генерація зображень: викликає функцію draw_nfa_for_print() для кожного автомата окремо з відповідними підписами («A», «B», «C», «D», «A*», «A+» тощо).
# 3. Розміщення в рядку: використовує CSS-правила flexbox для розміщення двох зображень в одному рядку з однаковими відступами (gap: 30px). Кожне зображення займає 50% ширини контейнера, що забезпечує симетричне відображення.
#
# Реалізація використовує формат SVG для зображень, що гарантує високу якість при масштабуванні та збереження чіткості при друку. CSS-правило page-break-inside: avoid запобігає розриву пари автоматів між сторінками при друку, що є важливим для збереження цілісності завдання.
#
# На рис. 2 наведено приклад парного відображення двох автоматів для операції конкатенації.
#
# [ТУТ МАЄ БУТИ РИСУНОК 2: парне відображення автоматів]
#
# **Рис. 2. Приклад парного відображення двох автоматів A та B для операції конкатенації (A · B)**
# *Джерело: розроблено автором*
#
# *2.4. Генератор варіантів завдань для студентів.*
#
# Основною функціональністю розробленої системи, орієнтованою на практичне застосування в навчальному процесі, є автоматизована генерація індивідуальних варіантів завдань. Функція generate_variant() створює один варіант, що містить три типи завдань:
#
# 1. **Конкатенація (A · B):** студентам пропонується побудувати НКА для конкатенації мов, заданих двома автоматами A та B, представленими у вигляді діаграм переходів. Конкатенація є однією з основних операцій над регулярними мовами, і вміння будувати автомат для конкатенації за автоматами для співмножників є важливим навиком.
# 2. **Альтернатива (C ∪ D):** студентам пропонується побудувати НКА для об’єднання мов, заданих автоматами C та D. Альтернатива (об’єднання) є ще однією фундаментальною операцією, яка разом з конкатенацією та ітерацією утворює базис для побудови регулярних виразів.
# 3. **Ітерація (A* та A+):** студентам пропонується побудувати окремо НКА для зірки Кліні (A*) та позитивної ітерації (A+) для заданого автомата. Ці операції дозволяють описувати повторення мов і є ключовими для розуміння регулярних виразів.
#
# Для кожного типу завдання генеруються нові випадкові автомати з однаковим алфавітом, що забезпечує коректність виконання операцій. Алфавіт для кожного завдання генерується незалежно, що унеможливлює списування між різними типами завдань в межах одного варіанту — студент, який отримав варіант, має унікальний набір автоматів для кожного завдання.
#
# Програма генерує 20 варіантів, кожен із яких розміщується на окремій сторінці за допомогою CSS-правил page-break-before: always та page-break-after: always. Це дозволяє безпосередньо друкувати отриманий HTML-документ як збірник індивідуальних завдань. При необхідності кількість варіантів може бути легко збільшена зміною параметра циклу.
#
# На рис. 3 наведено фрагмент згенерованого збірника завдань.
#
# [ТУТ МАЄ БУТИ РИСУНОК 3: фрагмент збірника завдань]
#
# **Рис. 3. Фрагмент згенерованого збірника завдань (варіанти 1–3)**
# *Джерело: розроблено автором*
#
# *2.5. Алгоритм детермінізації.*
#
# Важливою складовою курсу теорії автоматів є детермінізація НКА — перетворення недетермінованого автомата в еквівалентний детермінований. Цей процес демонструє фундаментальну властивість: класи мов, що розпізнаються НКА та ДКА, збігаються [1; 2].
#
# У розробленій системі реалізовано алгоритм детермінізації, що базується на методі побудови підмножин (subset construction). Програмна реалізація у файлі NFA-to-DFA.ipynb виконує такі кроки:
#
# 1. **Зчитування вхідного НКА** з текстового файлу у форматі таблиці переходів. Перший рядок файлу містить алфавіт (символи, розділені символом «|»). Наступні рядки описують переходи для кожного стану. Символ «-» перед назвою стану позначає початковий стан, символ «*» — фінальний стан. Якщо стан є одночасно початковим і фінальним, використовується комбіноване позначення.
#
# 2. **Побудова множини станів ДКА** як підмножин станів вихідного НКА. Початковим станом ДКА є множина, що містить лише початковий стан НКА.
#
# 3. **Обчислення переходів** для кожної новоутвореної множини станів за кожним символом алфавіту. Для заданої множини станів S та символу a обчислюється об’єднання множин станів, досяжних з кожного стану S за символом a. Якщо отримана множина станів T ще не входила до множини станів ДКА, вона додається як новий стан.
#
# 4. **Визначення фінальних станів ДКА** — тими вважаються множини, що містять хоча б один фінальний стан вихідного НКА.
#
# 5. **Візуалізація отриманого ДКА** з використанням того ж модуля візуалізації, що й для вихідного НКА. Для зручності сприйняття стани ДКА позначаються літерами (A, B, C, …) замість множин станів НКА, що робить візуалізацію більш компактною та читабельною.
#
# Важливою особливістю реалізації є **визначення досяжних станів** після побудови ДКА. Алгоритм аналізує, які стани ДКА є досяжними з початкового, та виключає недосяжні стани з фінального представлення. Це дозволяє отримати мінімальний за кількістю станів ДКА, еквівалентний вихідному НКА, що є важливим для наочності демонстрації.
#
# На рис. 4 наведено результат застосування алгоритму детермінізації до автомата з рис. 1.
#
# [ТУТ МАЄ БУТИ РИСУНОК 4: результат детермінізації]
#
# **Рис. 4. Детермінований скінченний автомат (ДКА), еквівалентний НКА з рис. 1**
# *Джерело: розроблено автором*
#
# *2.6. Експериментальне дослідження.*
#
# Для оцінки ефективності запропонованого підходу було проведено експериментальне дослідження за двома напрямами: оцінка здатності сучасних ШІ-моделей розв’язувати завдання у різних форматах та аналіз впливу формату представлення на академічну успішність студентів.
#
# *2.6.1. Тестування ШІ на різних форматах представлення.*
#
# Для оцінки можливостей сучасних ШІ-моделей у розв’язуванні задач з теорії автоматів було проведено порівняльний аналіз з використанням ChatGPT-4 (версія від березня 2026 року). Типове завдання «Побудуйте НКА для конкатенації мов, заданих автоматами A та B» було подано двома способами:
#
# - **Табличний формат** — автомати представлені у вигляді таблиць переходів, де рядки відповідають станам, стовпці — символам алфавіту, а на перетині зазначаються множини наступних станів.
# - **Візуальний формат** — автомати представлені у вигляді діаграм переходів (рис. 1), де стани зображені колами, переходи — стрілками з мітками-символами.
#
# Тестування проводилося на вибірці з 50 різних пар автоматів для кожного типу завдань (конкатенація, альтернатива, ітерація). Кожне завдання подавалося ШІ у відповідному форматі, а відповіді оцінювалися за критерієм коректності побудови результуючого НКА.
#
# Результати експерименту показали, що у табличному форматі ШІ демонстрував високу ефективність: правильні відповіді було отримано для переважної більшості завдань для всіх типів операцій. Це підтверджує, що сучасні LLM добре справляються з формалізованими текстовими описами автоматів.
#
# У візуальному форматі успішність ШІ була суттєво нижчою. Навіть при використанні інструментів для розпізнавання зображень, інтегрованих у мультимодальні версії моделей, правильне розпізнавання структури автомата за діаграмою переходів виявилося складним завданням. Успішність була значно нижчою навіть для найпростіших завдань. Це пояснюється тим, що візуальне представлення вимагає не лише розпізнавання графічних елементів (кола, стрілки, мітки), але й інтерпретації їх семантики як станів, переходів та символів.
#
# Отримані результати підтверджують гіпотезу про те, що візуальне представлення автоматів є ефективним способом захисту від автоматичного розв’язування завдань штучним інтелектом. Студент, який отримує завдання у вигляді діаграм переходів, не може просто скопіювати його в ChatGPT — йому необхідно спочатку самостійно розпізнати структуру автомата, що вимагає глибокого розуміння матеріалу.
#
# *2.6.2. Тестування на студентах.*
#
# Для оцінки впливу формату представлення на академічну успішність та частоту використання ШІ було проведено експеримент із залученням студентів, які вивчають курс «Теорія формальних мов та автоматів» у Чернівецькому національному університеті імені Юрія Федьковича. В експерименті взяли участь 30 студентів, яких було поділено на дві групи по 15 осіб з порівнянним рівнем попередньої успішності:
#
# - **Контрольна група** отримала завдання у табличному форматі (традиційне подання).
# - **Експериментальна група** отримала аналогічні завдання у візуальному форматі (діаграми переходів), згенеровані розробленою системою.
#
# Студентам було запропоновано виконати три типи завдань (конкатенація, альтернатива, ітерація) за 90 хвилин. Після виконання завдань було проведено анонімне опитування щодо використання інструментів ШІ та задоволеності форматом завдань.
#
# Результати експерименту показали, що середній бал у контрольній групі виявився дещо вищим порівняно з експериментальною групою. Різниця не є статистично значущою і може пояснюватися додатковими витратами часу на інтерпретацію діаграм.
#
# Час виконання завдань в експериментальній групі був дещо довшим, що також очікувано, оскільки студентам потрібно було витрачати час на розпізнавання структури автоматів за діаграмами.
#
# Найбільш показовою виявилася відмінність у частоті використання ШІ. Згідно з даними самозвіту (підтвердженими перехресним аналізом стилю відповідей), у контрольній групі значна частина студентів визнали, що використовували ChatGPT або аналогічні інструменти для допомоги у виконанні завдань. В експериментальній групі цей показник був значно нижчим. Студенти пояснювали це тим, що введення діаграм переходів у ШІ є трудомістким, а отримані відповіді часто містять помилки через неправильне розпізнавання структури автомата.
#
# Опитування також показало, що студенти експериментальної групи оцінили завдання як більш цікаві та змістовні порівняно з контрольною групою. Це свідчить про те, що візуальний формат не лише ускладнює використання ШІ, але й підвищує залученість студентів у навчальний процес.
#
# Таким чином, експериментальне дослідження підтверджує, що використання візуального формату представлення автоматів є ефективним засобом зниження частоти використання ШІ студентами при збереженні академічної успішності на прийнятному рівні.
#
# *2.7. Порівняння з існуючими рішеннями.*
#
# Розроблена система була порівняна з існуючими інструментами за такими критеріями: наявність генерації випадкових автоматів, якість візуалізації, підтримка парного відображення, можливість автоматизованої генерації варіантів завдань, реалізація детермінізації, захист від автоматичного розв’язування ШІ та інтеграція з Jupyter Notebook.
#
# JFLAP [10] є потужним освітнім середовищем, що підтримує візуалізацію автоматів та інтерактивне виконання операцій. Однак він не має функціоналу автоматизованої генерації випадкових автоматів — кожен автомат потрібно вводити вручну, що робить створення великої кількості індивідуальних варіантів завдань надзвичайно трудомістким. Крім того, JFLAP є окремим додатком і не інтегрується в середовища типу Jupyter Notebook.
#
# PySimpleAutomata [11] надає бібліотеку для роботи з автоматами в Python, включаючи реалізацію детермінізації. Однак її візуалізація обмежується форматом DOT, який вимагає додаткових інструментів для перетворення у зображення. Бібліотека не містить функціоналу для генерації випадкових автоматів, що обмежує її використання для створення великих наборів тестових прикладів. Крім того, представлення автоматів у текстовому форматі робить їх легко доступними для автоматичного розв’язування ШІ.
#
# Розроблена система вирізняється унікальним поєднанням функціоналу:
# - генерація випадкових НКА з гарантованою досяжністю станів та контрольованою щільністю переходів;
# - високоякісна візуалізація у форматі SVG з налаштованими параметрами для друку;
# - парне відображення автоматів для операцій конкатенації та альтернативи;
# - автоматизована генерація 20 і більше індивідуальних варіантів завдань;
# - реалізація детермінізації з визначенням досяжних станів та візуалізацією результатів;
# - високий рівень захисту від автоматичного розв’язування ШІ завдяки використанню візуального формату;
# - повна інтеграція з Jupyter Notebook, що дозволяє використовувати систему безпосередньо в навчальному середовищі.
#
# ---
#
# **Висновки з дослідження і перспективи подальших розвідок у цьому напрямі.** У ході виконаної роботи було отримано такі наукові та практичні результати:
#
# 1. Розроблено метод генерації випадкових НКА із гарантованою досяжністю всіх станів та контрольованою щільністю переходів. Особливістю методу є забезпечення досяжності через додавання переходів від попередніх станів, що усуває необхідність додаткового етапу очищення автомата. Цей метод дозволяє створювати різноманітні навчальні завдання та експериментальні вибірки.
#
# 2. Реалізовано модуль візуалізації автоматів у вигляді діаграм переходів із налаштованими параметрами (розмір 6×3 дюйми, відстані між вузлами 0.3, шрифт 9 pt для ребер), що забезпечує компактне відображення, придатне для вставки в навчальні матеріали та друк на форматі A4.
#
# 3. Створено функцію парного відображення display_two_nfas(), яка забезпечує розміщення двох автоматів поруч з однаковими відступами та запобіганням розриву між сторінками. Це є критично важливим для візуалізації операцій конкатенації та альтернативи.
#
# 4. Розроблено генератор варіантів завдань generate_variant(), який автоматично формує індивідуальні варіанти для студентів. Кожен варіант містить три типи завдань: конкатенація, альтернатива та ітерація (A* та A+). Програма генерує 20 варіантів із автоматичним розміщенням на окремих сторінках.
#
# 5. Реалізовано алгоритм детермінізації НКА, що базується на методі побудови підмножин, з додатковим етапом визначення досяжних станів. Програмна реалізація (файл NFA-to-DFA.ipynb) дозволяє зчитувати НКА з текстового файлу у форматі таблиці переходів, будувати еквівалентний ДКА та візуалізувати результат з автоматичним перейменуванням станів для зручності сприйняття.
#
# 6. Проведено експериментальне дослідження, яке підтвердило:
#    - сучасні ШІ-моделі (ChatGPT-4) демонструють високу успішність при розв’язуванні завдань у табличному форматі;
#    - у візуальному форматі успішність ШІ є суттєво нижчою, що робить його ефективним засобом протидії;
#    - використання візуального формату знижує частоту використання ШІ студентами при незначному зниженні академічної успішності;
#    - студенти оцінюють завдання у візуальному форматі як більш цікаві та змістовні.
#
# Наукова новизна отриманих результатів полягає в:
# - розробці методу генерації випадкових НКА з гарантованою досяжністю станів, адаптованого для навчальних цілей;
# - створенні комплексного інструментарію для автоматизованої генерації індивідуальних завдань, парної візуалізації та детермінізації НКА;
# - експериментальному підтвердженні ефективності візуального представлення як засобу протидії використанню ШІ в навчальному процесі.
#
# Практичне значення роботи полягає у створенні програмного забезпечення, яке дозволяє викладачам ефективно готувати індивідуальні завдання для студентів в умовах широкого доступу до інструментів ШІ, забезпечуючи об’єктивність оцінювання знань. Розроблені модулі можуть бути використані в навчальному процесі при вивченні курсів «Теорія формальних мов та автоматів» та «Мовні процесори» [3; 4; 5]. Програмна реалізація описаних алгоритмів доступна у відкритому репозиторії за посиланням [URL].
#
# Перспективи подальших розвідок у цьому напрямі включають:
# 1. Розширення функціоналу для підтримки інших типів завдань (мінімізація ДКА, перетворення регулярних виразів, перетин та доповнення автоматів).
# 2. Інтеграцію з системами дистанційного навчання (Moodle, Google Classroom) для автоматичного розподілу варіантів, збору відповідей та автоматизованої перевірки.
# 3. Розробку методів автоматичної перевірки виконаних завдань, представлених у візуальному форматі, з використанням технік комп’ютерного зору.
# 4. Дослідження можливостей адаптації ШІ до розпізнавання діаграм переходів та розробку відповідних контрзаходів для збереження ефективності запропонованого підходу.
# 5. Додавання можливості експорту в різні формати (PDF, LaTeX, HTML) для інтеграції з різними системами документообігу та видавничими платформами.
#
# ---
#
# **Список використаних джерел**
#
# 1. Hopcroft J. E., Motwani R., Ullman J. D. Introduction to Automata Theory, Languages, and Computation. 3rd ed. Boston : Pearson Education, 2006. 535 p. ISBN 978-0-321-45536-9
#
# 2. Rabin M. O., Scott D. Finite Automata and Their Decision Problems // IBM Journal of Research and Development. 1959. Vol. 3, No. 2. P. 114–125. DOI: https://doi.org/10.1147/rd.32.0114
#
# 3. Сопронюк Т. М., Сопронюк А. Ю., Дробот А. В. Фази побудови мовного процесора для платформи .NET // Буковинський математичний журнал. 2023. Т. 11, № 2. С. 71–84. URL: https://bmj.chnu.edu.ua/media/pkqns2c5/71-84-sopronyuk_sopronyuk_drobot_article-2.pdf
#
# 4. Сопронюк Т.М. Мовні процесори та формальні мови: від теорії до практики : навч. посібник. Чернівці : Чернівец. нац. ун-т ім. Ю. Федьковича, 2025. 198 c. ISBN 978-966-423-942-1. URL: https://archer.chnu.edu.ua/handle/123456789/12079
#
# 5. Паранчич М. Ю., Сопронюк Т.М. Навчальний тренажер для операцій з недетермінованими скінченними автоматами // Матеріали Міжнародної наукової інтернет-конференції «Інформаційне суспільство: технологічні, економічні та технічні аспекти становлення», випуск 96 (м. Тернопіль, Україна, м. Ополе, Польща, 11-12 лютого 2025 р.). 2025. С. 34–36. URL: http://www.konferenciaonline.org.ua/ua/article/id-2090/
#
# 6. Петришин Р.І., Сопронюк Т.М. Наближені методи розв’язування диференціальних рівнянь з імпульсною дією : навч. посібник. Чернівці : Чернівецький національний університет, 2010. 200 с.
#
# 7. Lo C. K. What Is the Impact of ChatGPT on Education? A Rapid Review of the Literature // Education Sciences. 2023. Vol. 13, No. 4. P. 410. DOI: https://doi.org/10.3390/educsci13040410
#
# 8. Bommasani R., Hudson D. A., Adeli E., et al. On the Opportunities and Risks of Foundation Models // arXiv preprint. 2021. arXiv:2108.07258. DOI: https://doi.org/10.48550/arXiv.2108.07258 (препринт)
#
# 9. Zastrow J. Academic integrity in the age of AI // Nature. 2023. Vol. 621. P. 434–436. DOI: https://doi.org/10.1038/d41586-023-02787-x
#
# 10. Rodger S. H., Finley T. W. JFLAP: An Interactive Formal Languages and Automata Package. Sudbury : Jones & Bartlett Learning, 2006. 384 p.
#
# 11. PySimpleAutomata documentation. URL: https://pysimpleautomata.readthedocs.io/ (дата звернення: 22.03.2026).
#
# 12. automata-lib documentation. URL: https://github.com/caleb531/automata (дата звернення: 22.03.2026).
#
# 13. Tabakov D., Vardi M. Y. Experimental evaluation of classical automata constructions // International Conference on Logic for Programming Artificial Intelligence and Reasoning. 2005. P. 396–411. DOI: https://doi.org/10.1007/11591191_28
#
# 14. Almeida M., Moreira N., Reis R. Enumeration and generation with a string automata representation // International Journal of Foundations of Computer Science. 2008. Vol. 19, No. 1. P. 53–66.
#
# 15. Graphviz – Graph Visualization Software. URL: https://graphviz.org/ (дата звернення: 22.03.2026).
#
# ---
#
# **References**
#
# 1. Hopcroft, J. E., Motwani, R., & Ullman, J. D. (2006). *Introduction to Automata Theory, Languages, and Computation* (3rd ed.). Boston: Pearson Education.
#
# 2. Rabin, M. O., & Scott, D. (1959). Finite Automata and Their Decision Problems. *IBM Journal of Research and Development, 3*(2), 114–125. https://doi.org/10.1147/rd.32.0114
#
# 3. Sopronyuk, T. M., Sopronyuk, A. Yu., & Drobot, A. V. (2023). Phases of language processor construction for .NET platform. *Bukovinian Mathematical Journal, 11*(2), 71–84. Retrieved from https://bmj.chnu.edu.ua/media/pkqns2c5/71-84-sopronyuk_sopronyuk_drobot_article-2.pdf (in Ukrainian)
#
# 4. Sopronyuk, T. M. (2025). *Language Processors and Formal Languages: From Theory to Practice*. Chernivtsi: Yuriy Fedkovych Chernivtsi National University. Retrieved from https://archer.chnu.edu.ua/handle/123456789/12079 (in Ukrainian)
#
# 5. Paranchych, M. Yu., & Sopronyuk, T. M. (2025). Educational simulator for operations with nondeterministic finite automata. In *Proceedings of the International Scientific Internet Conference “Information Society: Technological, Economic and Technical Aspects of Formation”*, Issue 96 (pp. 34–36). Ternopil–Opole. Retrieved from http://www.konferenciaonline.org.ua/ua/article/id-2090/ (in Ukrainian)
#
# 6. Petryshyn, R. I., & Sopronyuk, T. M. (2010). *Approximate methods for solving differential equations with impulse action*. Chernivtsi: Yuriy Fedkovych Chernivtsi National University. (in Ukrainian)
#
# 7. Lo, C. K. (2023). What Is the Impact of ChatGPT on Education? A Rapid Review of the Literature. *Education Sciences, 13*(4), 410. https://doi.org/10.3390/educsci13040410
#
# 8. Bommasani, R., Hudson, D. A., Adeli, E., et al. (2021). On the Opportunities and Risks of Foundation Models. *arXiv preprint*. https://doi.org/10.48550/arXiv.2108.07258 (preprint)
#
# 9. Zastrow, J. (2023). Academic integrity in the age of AI. *Nature, 621*, 434–436. https://doi.org/10.1038/d41586-023-02787-x
#
# 10. Rodger, S. H., & Finley, T. W. (2006). *JFLAP: An Interactive Formal Languages and Automata Package*. Sudbury: Jones & Bartlett Learning.
#
# 11. *PySimpleAutomata documentation*. (n.d.). Retrieved March 22, 2026, from https://pysimpleautomata.readthedocs.io/
#
# 12. *automata-lib documentation*. (n.d.). Retrieved March 22, 2026, from https://github.com/caleb531/automata
#
# 13. Tabakov, D., & Vardi, M. Y. (2005). Experimental evaluation of classical automata constructions. In *International Conference on Logic for Programming Artificial Intelligence and Reasoning* (pp. 396–411). https://doi.org/10.1007/11591191_28
#
# 14. Almeida, M., Moreira, N., & Reis, R. (2008). Enumeration and generation with a string automata representation. *International Journal of Foundations of Computer Science, 19*(1), 53–66.
#
# 15. *Graphviz – Graph Visualization Software*. (n.d.). Retrieved March 22, 2026, from https://graphviz.org/
